# %%
# !ls
# Out:
# baseline_resnet_imsitu.pth  imsitu_dataset	      sample_data
# imsitu_annotated.json	    of500_images_resized.tar

# %%
# !du -h baseline_resnet_imsitu.pth
# Out:
# 94M	baseline_resnet_imsitu.pth

# %%
# !pip install pyuploadcare -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.8/367.8 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 31.4 MB/s eta 0:00:00

# %%
from pyuploadcare import Uploadcare, File

uploadcare = Uploadcare(public_key='43189ed23a5312d4ede8', secret_key='598681585144a03347f7')
with open('baseline_resnet_imsitu.pth', 'rb') as file_object:
    ucare_file = uploadcare.upload(file_object)

# %%
from pyuploadcare import Uploadcare, File

uploadcare = Uploadcare(public_key='43189ed23a5312d4ede8', secret_key='598681585144a03347f7')
with open('debaised_resnet_adv@conv5.pth', 'rb') as file_object:
    ucare_file = uploadcare.upload(file_object)

# %%
from pyuploadcare import Uploadcare, File

uploadcare = Uploadcare(public_key='43189ed23a5312d4ede8', secret_key='598681585144a03347f7')
with open('debaised_resnet_adv@conv4.pth', 'rb') as file_object:
    ucare_file = uploadcare.upload(file_object)
